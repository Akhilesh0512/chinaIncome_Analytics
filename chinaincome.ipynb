# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
df = pd.read_csv('ChinaIncome.csv')
df
# Out:
#     rownames  agriculture  commerce  construction  industry  transport
# 0          1        100.0     100.0         100.0     100.0      100.0
# 1          2        101.6     133.0         138.1     133.6      120.0
# 2          3        103.3     136.4         133.3     159.1      136.0
# 3          4        111.5     137.5         152.4     169.1      140.0
# 4          5        116.5     146.6         261.9     219.1      164.0
# 5          6        120.1     146.6         242.9     244.5      176.0
# 6          7        120.3     155.9         367.0     383.5      270.8
# 7          8        100.6     170.3         388.6     501.5      356.5
# 8          9         83.6     164.1         394.0     541.4      383.6
# 9         10         84.7     130.1         129.5     315.9      221.1
# 10        11         88.7     117.7         161.9     267.4      171.5
# 11        12         98.9     120.8         205.1     300.7      176.0
# 12        13        111.9     123.9         259.0     374.9      198.6
# 13        14        122.9     128.0         286.0     477.7      261.7
# 14        15        131.9     155.9         313.0     598.5      297.8
# 15        16        134.2     164.1         296.8     504.3      239.2
# 16        17        131.6     151.8         237.5     458.6      225.6
# 17        18        132.2     179.6         323.8     622.3      284.3
# 18        19        139.8     199.2         421.0     863.0      343.0
# 19        20        142.0     201.2         468.3     979.0      370.8
# 20        21        140.5     208.0         452.5    1043.5      389.3
# 21        22        153.1     224.5         457.8    1134.3      412.5
# 22        23        159.2     220.6         484.1    1128.9      394.0
# 23        24        162.3     220.6         542.0    1297.3      444.9
# 24        25        159.1     214.8         568.3    1249.2      426.4
# 25        26        155.1     242.0         578.8    1434.0      491.3
# 26        27        161.2     296.4         573.5    1679.1      546.9
# 27        28        171.5     316.8         584.1    1814.7      560.8
# 28        29        168.4     318.8         757.7    2012.7      584.0
# 29        30        180.4     379.4         770.0    2046.8      607.2
# 30        31        201.6     397.5         806.9    2170.1      681.3
# 31        32        218.7     449.1         954.3    2383.7      755.5
# 32        33        247.0     499.5        1056.7    2738.8      852.8
# 33        34        253.7     593.7        1310.6    3275.2     1024.3
# 34        35        261.4     636.3        1540.0    3590.6     1140.2
# 35        36        273.2     715.0        1744.8    4058.8     1269.9
# 36        37        279.4     760.8        1884.0    4765.0     1413.6

# %%
import pandas as pd

# Read the CSV file into a DataFrame
input_csv_file = 'ChinaIncome.csv'
output_csv_file = 'output_csv_file'

df = pd.read_csv(input_csv_file)

# Remove duplicate rows from the DataFrame
cleaned_df = df.drop_duplicates()

# Write the cleaned DataFrame to a new CSV file
cleaned_df.to_csv(output_csv_file, index=False)

print("Duplicate values removed and saved to", output_csv_file)
# Out:
# Duplicate values removed and saved to output_csv_file

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
df = pd.read_csv('output_csv_file')
df
# Out:
#     rownames  agriculture  commerce  construction  industry  transport
# 0          1        100.0     100.0         100.0     100.0      100.0
# 1          2        101.6     133.0         138.1     133.6      120.0
# 2          3        103.3     136.4         133.3     159.1      136.0
# 3          4        111.5     137.5         152.4     169.1      140.0
# 4          5        116.5     146.6         261.9     219.1      164.0
# 5          6        120.1     146.6         242.9     244.5      176.0
# 6          7        120.3     155.9         367.0     383.5      270.8
# 7          8        100.6     170.3         388.6     501.5      356.5
# 8          9         83.6     164.1         394.0     541.4      383.6
# 9         10         84.7     130.1         129.5     315.9      221.1
# 10        11         88.7     117.7         161.9     267.4      171.5
# 11        12         98.9     120.8         205.1     300.7      176.0
# 12        13        111.9     123.9         259.0     374.9      198.6
# 13        14        122.9     128.0         286.0     477.7      261.7
# 14        15        131.9     155.9         313.0     598.5      297.8
# 15        16        134.2     164.1         296.8     504.3      239.2
# 16        17        131.6     151.8         237.5     458.6      225.6
# 17        18        132.2     179.6         323.8     622.3      284.3
# 18        19        139.8     199.2         421.0     863.0      343.0
# 19        20        142.0     201.2         468.3     979.0      370.8
# 20        21        140.5     208.0         452.5    1043.5      389.3
# 21        22        153.1     224.5         457.8    1134.3      412.5
# 22        23        159.2     220.6         484.1    1128.9      394.0
# 23        24        162.3     220.6         542.0    1297.3      444.9
# 24        25        159.1     214.8         568.3    1249.2      426.4
# 25        26        155.1     242.0         578.8    1434.0      491.3
# 26        27        161.2     296.4         573.5    1679.1      546.9
# 27        28        171.5     316.8         584.1    1814.7      560.8
# 28        29        168.4     318.8         757.7    2012.7      584.0
# 29        30        180.4     379.4         770.0    2046.8      607.2
# 30        31        201.6     397.5         806.9    2170.1      681.3
# 31        32        218.7     449.1         954.3    2383.7      755.5
# 32        33        247.0     499.5        1056.7    2738.8      852.8
# 33        34        253.7     593.7        1310.6    3275.2     1024.3
# 34        35        261.4     636.3        1540.0    3590.6     1140.2
# 35        36        273.2     715.0        1744.8    4058.8     1269.9
# 36        37        279.4     760.8        1884.0    4765.0     1413.6

# %%
import pandas as pd

# Load the original CSV file and the cleaned (non-duplicate) CSV file
original_df = pd.read_csv('ChinaIncome.csv')
cleaned_df = pd.read_csv('output_csv_file')

# Compare the number of rows and columns in both DataFrames
print("Original file shape:", original_df.shape)
print("Cleaned file shape:", cleaned_df.shape)

# Check for differences in specific columns or rows
# For example, you can check if there are any rows that exist in the original file but not in the cleaned file
difference_rows = original_df[~original_df.isin(cleaned_df)].dropna()
print("Rows in original file but not in cleaned file:")
print(difference_rows)

# You can also compare specific columns
difference_columns = original_df[~original_df['agriculture'].isin(cleaned_df['agriculture'])]
print("Rows in original file with ColumnA values not present in cleaned file:")
print(difference_columns)

# Check if the two DataFrames are entirely equal
are_equal = original_df.equals(cleaned_df)
print("Are the two DataFrames equal?", are_equal)
# Out:
# Original file shape: (37, 6)
# Cleaned file shape: (37, 6)
# Rows in original file but not in cleaned file:
# Empty DataFrame
# Columns: [rownames, agriculture, commerce, construction, industry, transport]
# Index: []
# Rows in original file with ColumnA values not present in cleaned file:
# Empty DataFrame
# Columns: [rownames, agriculture, commerce, construction, industry, transport]
# Index: []
# Are the two DataFrames equal? True

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('ChinaIncome.csv')

# Display the first few rows of the DataFrame to inspect the data
print("Original DataFrame:")
print(df.head())

# Data Cleaning
# Example: Remove duplicates
df_cleaned = df.drop_duplicates()
# Data Transformation
# Example: Create new feature using existing features
df_cleaned['new_feature'] = df_cleaned['agriculture'] * df_cleaned['commerce']

# Data Validation
# Check for missing values
print("Missing values after cleaning:")
print(df_cleaned.isnull().sum())

# Save the cleaned and transformed DataFrame back to a new CSV file
df_cleaned.to_csv('cleaned_data.csv', index=False)

print("Data wrangling complete. Cleaned data saved to 'cleaned_data.csv'.")
# Out:
# Original DataFrame:
#    rownames  agriculture  commerce  construction  industry  transport
# 0         1        100.0     100.0         100.0     100.0      100.0
# 1         2        101.6     133.0         138.1     133.6      120.0
# 2         3        103.3     136.4         133.3     159.1      136.0
# 3         4        111.5     137.5         152.4     169.1      140.0
# 4         5        116.5     146.6         261.9     219.1      164.0
# Missing values after cleaning:
# rownames        0
# agriculture     0
# commerce        0
# construction    0
# industry        0
# transport       0
# new_feature     0
# dtype: int64
# Data wrangling complete. Cleaned data saved to 'cleaned_data.csv'.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
df = pd.read_csv('cleaned_data.csv')

# Display basic information about the dataset
print("Dataset Information:")
print(df.info())

# Display summary statistics for numerical columns
print("\nSummary Statistics:")
print(df.describe())

# Display the first few rows of the DataFrame
print("\nFirst few rows of the DataFrame:")
print(df.head())

# Data Visualization
# Example: Histogram of a numerical column
plt.figure(figsize=(8, 6))
plt.hist(df['agriculture'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Numerical Column')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Example: Box plot of a numerical column
plt.figure(figsize=(8, 6))
plt.boxplot(df['commerce'])
plt.title('Box plot of Numerical Column')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# Example: Scatter plot of two numerical columns
plt.figure(figsize=(8, 6))
plt.scatter(df['construction'], df['commerce'], color='green', alpha=0.5)
plt.title('Scatter plot of Numerical Column 1 vs Numerical Column 2')
plt.xlabel('Numerical Column 1')
plt.ylabel('Numerical Column 2')
plt.grid(True)
plt.show()

# Example: Bar chart of a categorical column
plt.figure(figsize=(8, 6))
df['transport'].value_counts().plot(kind='bar', color='orange')
plt.title('Bar Chart of Categorical Column')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rownames      37 non-null     int64
#  1   agriculture   37 non-null     float64
#  2   commerce      37 non-null     float64
#  3   construction  37 non-null     float64
#  4   industry      37 non-null     float64
#  5   transport     37 non-null     float64
#  6   new_feature   37 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 2.1 KB
# None
#
# Summary Statistics:
#         rownames  agriculture    commerce  construction     industry  \
# count  37.000000    37.000000   37.000000     37.000000    37.000000
# mean   19.000000   151.948649  260.986486    549.897297  1244.237838
# std    10.824355    54.391863  176.233007    448.051786  1191.844162
# min     1.000000    83.600000  100.000000    100.000000   100.000000
# 25%    10.000000   111.900000  146.600000    259.000000   374.900000
# 50%    19.000000   139.800000  199.200000    421.000000   863.000000
# 75%    28.000000   168.400000  316.800000    584.100000  1814.700000
# max    37.000000   279.400000  760.800000   1884.000000  4765.000000
#
#          transport    new_feature
# count    37.000000      37.000000
# mean    449.497297   48648.800270
# std     328.546232   53689.377004
# min     100.000000   10000.000000
# 25%     221.100000   15731.200000
# 50%     370.800000   27848.160000
# 75%     560.800000   53685.920000
# max    1413.600000  212567.520000
#
# First few rows of the DataFrame:
#    rownames  agriculture  commerce  construction  industry  transport  \
# 0         1        100.0     100.0         100.0     100.0      100.0
# 1         2        101.6     133.0         138.1     133.6      120.0
# 2         3        103.3     136.4         133.3     159.1      136.0
# 3         4        111.5     137.5         152.4     169.1      140.0
# 4         5        116.5     146.6         261.9     219.1      164.0
#
#    new_feature
# 0     10000.00
# 1     13512.80
# 2     14090.12
# 3     15331.25
# 4     17078.90

# %%
# Conclusion based on data exploration

# Dataset Information
dataset_info = df.info()
print("Dataset Information:")
print(dataset_info)
print("\n")

# Summary Statistics
summary_statistics = df.describe()
print("Summary Statistics:")
print(summary_statistics)
print("\n")

# First Few Rows of the DataFrame
first_few_rows = df.head()
print("First few rows of the DataFrame:")
print(first_few_rows)
print("\n")

# Data Quality
# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)
print("\n")

# Data Visualization
# Include observations from visualizations (histograms, box plots, scatter plots, bar charts)

# Conclusion
print("Conclusion:")
print("1. The dataset contains {} rows and {} columns.".format(df.shape[0], df.shape[1]))
print("2. Summary statistics provide insights into the distribution and central tendency of numerical variables.")
print("3. The first few rows of the DataFrame give a glimpse of the actual data and its format.")
print("4. Missing values are present in certain columns and need to be addressed through imputation or removal.")
print("5. Visualizations reveal patterns, relationships, and distributions within the data.")
print("6. Further analysis is warranted to explore correlations, trends, and potential insights that can guide decision-making.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rownames      37 non-null     int64
#  1   agriculture   37 non-null     float64
#  2   commerce      37 non-null     float64
#  3   construction  37 non-null     float64
#  4   industry      37 non-null     float64
#  5   transport     37 non-null     float64
#  6   new_feature   37 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 2.1 KB
# Dataset Information:
# None
#
#
# Summary Statistics:
#         rownames  agriculture    commerce  construction     industry  \
# count  37.000000    37.000000   37.000000     37.000000    37.000000
# mean   19.000000   151.948649  260.986486    549.897297  1244.237838
# std    10.824355    54.391863  176.233007    448.051786  1191.844162
# min     1.000000    83.600000  100.000000    100.000000   100.000000
# 25%    10.000000   111.900000  146.600000    259.000000   374.900000
# 50%    19.000000   139.800000  199.200000    421.000000   863.000000
# 75%    28.000000   168.400000  316.800000    584.100000  1814.700000
# max    37.000000   279.400000  760.800000   1884.000000  4765.000000
#
#          transport    new_feature
# count    37.000000      37.000000
# mean    449.497297   48648.800270
# std     328.546232   53689.377004
# min     100.000000   10000.000000
# 25%     221.100000   15731.200000
# 50%     370.800000   27848.160000
# 75%     560.800000   53685.920000
# max    1413.600000  212567.520000
#
#
# First few rows of the DataFrame:
#    rownames  agriculture  commerce  construction  industry  transport  \
# 0         1        100.0     100.0         100.0     100.0      100.0
# 1         2        101.6     133.0         138.1     133.6      120.0
# 2         3        103.3     136.4         133.3     159.1      136.0
# 3         4        111.5     137.5         152.4     169.1      140.0
# 4         5        116.5     146.6         261.9     219.1      164.0
#
#    new_feature
# 0     10000.00
# 1     13512.80
# 2     14090.12
# 3     15331.25
# 4     17078.90
#
#
# Missing Values:
# rownames        0
# agriculture     0
# commerce        0
# construction    0
# industry        0
# transport       0
# new_feature     0
# dtype: int64
#
#
# Conclusion:
# 1. The dataset contains 37 rows and 7 columns.
# 2. Summary statistics provide insights into the distribution and central tendency of numerical variables.
# 3. The first few rows of the DataFrame give a glimpse of the actual data and its format.
# 4. Missing values are present in certain columns and need to be addressed through imputation or removal.
# 5. Visualizations reveal patterns, relationships, and distributions within the data.
# 6. Further analysis is warranted to explore correlations, trends, and potential insights that can guide decision-making.
